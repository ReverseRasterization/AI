# %%
import pandas as pd
import seaborn as sb
import numpy as np

df = pd.read_json('games.json')
df2 = pd.read_json('gamesET.json')

# %%
df.columns
# Out:
# Index(['ID', 'name', 'release_date', 'estimated_owners', 'peak_ccu',
#        'required_age', 'price', 'dlc_count', 'main_description',
#        'supported_languages', 'full_audio_languages', 'reviews',
#        'header_image', 'website', 'support_url', 'support_email', 'windows',
#        'mac', 'linux', 'metacritic_score', 'metacriticURL', 'user_score',
#        'positive', 'negative', 'score_rank', 'achievements', 'recommendations',
#        'notes', 'average_playtime_forever', 'average_playtime_2weeks',
#        'median_playtime_forever', 'packages', 'developers', 'publishers',
#        'categories', 'genres', 'tags', 'screenshots'],
#       dtype='object')

# %%
filtered_df = df[df['name'].str.contains('Call of Duty', na=False)]

rows = filtered_df.to_dict('records')


filtered_df
# Out:
#             ID                                              name  \
# 136       7940                  Call of Duty® 4: Modern Warfare®
# 3073     42710                          Call of Duty®: Black Ops
# 7629    393080         Call of Duty®: Modern Warfare® Remastered
# 8176    202990                       Call of Duty®: Black Ops II
# 15118   311210                      Call of Duty®: Black Ops III
# 16436   209160                             Call of Duty®: Ghosts
# 20805     2640                    Call of Duty: United Offensive
# 21930   209650    Call of Duty®: Advanced Warfare - Gold Edition
# 22085   209660    Call of Duty®: Advanced Warfare - Gold Edition
# 24094   476600                               Call of Duty®: WWII
# 27498    10090                        Call of Duty: World at War
# 29125    42680                  Call of Duty®: Modern Warfare® 3
# 29670    42700                          Call of Duty®: Black Ops
# ...

# %%
print(df['price'].max())
print(df['recommendations'].max())
print(df[df['recommendations'] == df['recommendations'].max()])
df = df.drop([81901,82971, 46158])
sb.scatterplot(data=df, x=df['price'], y=df['recommendations'])
# Out:
# 999.98
# 3441592
#         ID                              name  release_date  \
# 46158  730  Counter-Strike: Global Offensive  Aug 21, 2012
#
#            estimated_owners  peak_ccu  required_age  price  dlc_count  \
# 46158  50000000 - 100000000    825215             0    0.0          0
#
#                                         main_description  \
# 46158  Counter-Strike: Global Offensive (CS: GO) expa...
#
#                                      supported_languages  ...  \
# 46158  ['Czech', 'Danish', 'Dutch', 'English', 'Finni...  ...
#
#       average_playtime_forever average_playtime_2weeks  \
# 46158                    30484                     777
#
#       median_playtime_forever packages                       developers  \
# 46158                    6357      253  Valve,Hidden Path Entertainment
#
#       publishers                                         categories  \
# 46158      Valve  Multi-player,Steam Achievements,Full controlle...
#
# ...

# %% [markdown]
# The relationship between the price and recommendations of a game is in a negative direction. The relationship between the two factors is very weak. However, it appears that the lower the price, the less recommandations it gets

# %%
df[df['negative'] == df['negative'].max()]
# Out:
#            ID                name  release_date     estimated_owners  \
# 57205  271590  Grand Theft Auto V  Apr 13, 2015  20000000 - 50000000
#
#        peak_ccu  required_age  price  dlc_count  \
# 57205    170527            17    0.0          0
#
#                                         main_description  \
# 57205  When a young street hustler, a retired bank ro...
#
#                                      supported_languages  ...  \
# 57205  ['English', 'French', 'Italian', 'German', 'Sp...  ...
#
#       average_playtime_forever average_playtime_2weeks  \
# 57205                    13650                     656
#
#       median_playtime_forever packages      developers      publishers  \
# 57205                    6274      154  Rockstar North  Rockstar Games
#
#                                               categories            genres  \
# 57205  Single-player,Multi-player,PvP,Online PvP,Co-o...  Action,Adventure
#
#                                                     tags  \
# ...

# %%
#df = df.drop(index = 57205, inplace=False)
print(df['negative'].max())
sb.scatterplot(data=df, x=df['positive'], y=df['negative'])
df.corr()['negative']
df.corr()['positive']
# Out:
# 138530
# ID                         -0.078249
# peak_ccu                    0.251530
# required_age                0.127283
# price                       0.067546
# dlc_count                        NaN
# windows                     0.001153
# mac                         0.037859
# linux                       0.036412
# metacritic_score            0.193667
# user_score                 -0.001101
# positive                    1.000000
# negative                    0.722098
# score_rank                  0.158575
# achievements                0.022577
# recommendations             0.856719
# average_playtime_forever    0.181550
# average_playtime_2weeks     0.162362
# median_playtime_forever     0.036975
# packages                    0.111455
# Name: positive, dtype: float64

# %% [markdown]
# The correlation between negative and positive reviews are strong because it has a correlation score of about .7. With outliars, the correlation is .78.

# %%
def drawScatter(dfa, x, y, num_outliers):
    idx = []

    for i in range(num_outliers):
        idx = dfa[x].idxmax()
        dfa.drop([idx], inplace=True)

    sb.scatterplot(data=dfa, x=x, y=y)

drawScatter(df2, df2['user_reviews'], df2['price_original'], 3)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_25156\1748275650.py in <module>
#       8     sb.scatterplot(data=dfa, x=x, y=y)
#       9
# ---> 10 drawScatter(df2, df2['user_reviews'], df2['price_original'], 3)
#
# ~\AppData\Local\Temp\ipykernel_25156\1748275650.py in drawScatter(dfa, x, y, num_outliers)
#       3
#       4     for i in range(num_outliers):
# ----> 5         idx = dfa[x].idxmax()
#       6         dfa.drop([idx], inplace=True)
#       7
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    3509             if is_iterator(key):
#    3510                 key = list(key)
# -> 3511             indexer = self.columns._get_indexer_strict(key, "columns")[1]
#    3512
#    3513         # take() does not accept boolean indexers
#
# ...

# %%
df2[df2['price_final'] == df2['price_final'].max()]
# Out:
#        app_id          title date_release   win   mac  linux         rating  \
# 19819  502570  Houdini Indie   2018-10-10  True  True  False  Very Positive
#
#        positive_ratio  user_reviews  price_final  price_original  discount  \
# 19819              94           148       269.99          269.99         0
#
#        steam_deck
# 19819        True
